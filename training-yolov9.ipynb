# %%
import torch
print("CUDA is available: ", torch.cuda.is_available())
print("Number of GPUs: ", torch.cuda.device_count())
# Out:
# CUDA is available:  True
# Number of GPUs:  1

# %%
Load_data = r"C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9"

# %%
# %cd r"C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9"
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'r"C:\\Users\\LENOVO\\Desktop\\Data_UTV\\Data_UTV\\YOLOv9"'
# c:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9

# %%
# %pwd
# Out:
# 'c:\\Users\\LENOVO\\Desktop\\Data_UTV\\Data_UTV\\YOLOv9'

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from ultralytics import YOLO

# Load the model
model = YOLO(r"C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9\yolov9t.pt")

# Use the model
results = model.train(data=r"C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9\data.yaml", epochs=100, batch=16)
# Out:
# Ultralytics YOLOv8.2.82  Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
from ultralytics import YOLO
# !yolo predict model=r'C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9\runs\detect\train2\weights\best.pt' source=r'C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9\test\images\Malignant-370-_png.rf.aa433b5d8fb27593aeaf27d92afa88a2.jpg'
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.9.19 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# YOLOv9t summary (fused): 486 layers, 1,971,369 parameters, 0 gradients, 7.6 GFLOPs
#
# image 1/1 C:\Users\LENOVO\Desktop\Data_UTV\Data_UTV\YOLOv9\test\images\Malignant-370-_png.rf.aa433b5d8fb27593aeaf27d92afa88a2.jpg: 640x640 1 Malignant, 1 Normal, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 66.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
